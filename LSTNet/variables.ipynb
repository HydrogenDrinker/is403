# %%
import pandas as pd

# %% [markdown]
# ### RangeIndex: Số dòng - Time steps
# ### Columns: Số cột - Variables

# %%
ele=pd.read_csv('data/electricity.txt')
traffic=pd.read_csv('data/traffic.txt')
solar=pd.read_csv('data/solar_AL.txt')
exchange=pd.read_csv('data/exchange_rate.txt')

# %%
ele.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26303 entries, 0 to 26302
# Columns: 321 entries, 14.000000 to 2162.000000
# dtypes: float64(321)
# memory usage: 64.4 MB

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17543 entries, 0 to 17542
# Columns: 862 entries, 0.004800 to 0.012100.5
# dtypes: float64(862)
# memory usage: 115.4 MB

# %%
solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52559 entries, 0 to 52558
# Columns: 137 entries, 0.000000000000000000e+00 to 0.000000000000000000e+00.136
# dtypes: float64(137)
# memory usage: 54.9 MB

# %%
exchange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7587 entries, 0 to 7586
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   0.785500  7587 non-null   float64
#  1   1.611000  7587 non-null   float64
#  2   0.861698  7587 non-null   float64
#  3   0.634196  7587 non-null   float64
#  4   0.211242  7587 non-null   float64
#  5   0.006838  7587 non-null   float64
#  6   0.593000  7587 non-null   float64
#  7   0.525486  7587 non-null   float64
# dtypes: float64(8)
# memory usage: 474.3 KB
