# %%
import pandas as pd
import os
import sys
import numpy as np

# %%
import pandas as pd
import os
import sys
import numpy as np
import ast

def show_training_log(file_path, save_txt_path=None):
    """
    Hàm đọc file history (dạng dictionary chứa NaN và Infinity)
    """
    
    if not os.path.exists(file_path):
        print(f"❌ Lỗi: Không tìm thấy file tại '{file_path}'")
        return

    try:
        with open(file_path, 'r') as f:
            content = f.read().strip()
            
        try:
            # Định nghĩa từ điển để Python hiểu các từ lạ trong file
            context = {
                'NaN': np.nan, 
                'nan': np.nan,
                'Infinity': np.inf,
                'inf': np.inf,
                '-Infinity': -np.inf
            }
            
            data_dict = eval(content, {}, context)
            
            df = pd.DataFrame(data_dict)
            
        except Exception as e:
            print(f"⚠️ Lỗi parse Dictionary: {e}")
            print("👉 Đang thử đọc như CSV thông thường...")
            df = pd.read_csv(file_path)

        total_epochs = len(df)
        f_out = open(save_txt_path, 'w') if save_txt_path else None
        
        def log(text):
            print(text)
            if f_out: f_out.write(text + "\n")

        log("=" * 60)
        log(f"TRAINING LOG RECONSTRUCTION")
        log(f"Source: {os.path.basename(file_path)}")
        log(f"Total Epochs: {total_epochs}")
        log("=" * 60)
        log("") 

        if total_epochs == 0:
            print("❌ File rỗng.")
            return

        for i, row in df.iterrows():
            epoch = i + 1
            
            loss = row.get('loss', float('nan'))
            rse = row.get('rse', float('nan'))
            corr = row.get('corr', float('nan'))
            
            val_loss = row.get('val_loss', float('nan'))
            val_rse = row.get('val_rse', float('nan'))
            val_corr = row.get('val_corr', float('nan'))

            log(f"Epoch {epoch}/{total_epochs}")
            
            # Format chuỗi, xử lý in ra 'inf' nếu là vô cực
            log_line = (f"val_loss={val_loss:.6f}, val_rse={val_rse}, val_corr={val_corr}, "
                        f"loss={loss:.6f}, rse={rse:.6f}, corr={corr:.6f}")
            
            log(log_line)
            log("-" * 60) 

        if f_out:
            print(f"\n✅ Đã lưu log ra file: {save_txt_path}")
            f_out.close()
            
    except Exception as e:
        print(f"❌ Có lỗi xảy ra: {e}")
# Out:
# --- SOLAR FILE ---
# ❌ Lỗi: Không tìm thấy file tại 'save/full/solar3_history.csv'

# %% [markdown]
# ## Training log của bộ dữ liệu electricity.txt

# %%
show_training_log('../LSTNet/save/full/electricity/electricity3_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: electricity3_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.097837, val_rse=0.7254107223334727, val_corr=nan, loss=0.209483, rse=1.339440, corr=0.272743
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.076266, val_rse=0.6006890916253332, val_corr=nan, loss=0.085466, rse=0.603971, corr=0.691317
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.068183, val_rse=0.5548397881226539, val_corr=nan, loss=0.072684, rse=0.531817, corr=0.762160
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.065971, val_rse=0.544931421792455, val_corr=nan, loss=0.068477, rse=0.509699, corr=0.784539
# ------------------------------------------------------------
# Epoch 5/25
# val_loss=0.061573, val_rse=0.5160292526701743, val_corr=nan, loss=0.064267, rse=0.487584, corr=0.805070
# ------------------------------------------------------------
# ...

# %%
show_training_log('../LSTNet/save/full/electricity/electricity6_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: electricity6_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.132134, val_rse=0.9687312586727624, val_corr=nan, loss=0.251833, rse=1.648841, corr=0.110771
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.099369, val_rse=0.7389906367134446, val_corr=nan, loss=0.117787, rse=0.810111, corr=0.559743
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.082160, val_rse=0.6193145457453384, val_corr=nan, loss=0.093648, rse=0.650751, corr=0.686917
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.070635, val_rse=0.5373466153308888, val_corr=nan, loss=0.079173, rse=0.552742, corr=0.757886
# ------------------------------------------------------------
# Epoch 5/25
# val_loss=0.063337, val_rse=0.48395254527677306, val_corr=nan, loss=0.068989, rse=0.483626, corr=0.807135
# ------------------------------------------------------------
# ...

# %%
show_training_log('../LSTNet/save/full/electricity/electricity12_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: electricity12_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.080204, val_rse=0.6172385601076511, val_corr=nan, loss=0.100670, rse=0.683386, corr=0.626409
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.070641, val_rse=0.5576231007656655, val_corr=nan, loss=0.075938, rse=0.543203, corr=0.766942
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.064151, val_rse=0.5180526595789995, val_corr=nan, loss=0.068094, rse=0.497211, corr=0.803614
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.059021, val_rse=0.48856977856990796, val_corr=nan, loss=0.062255, rse=0.464628, corr=0.826121
# ------------------------------------------------------------
# Epoch 5/25
# val_loss=0.055016, val_rse=0.4676896152308721, val_corr=nan, loss=0.057617, rse=0.440585, corr=0.841817
# ------------------------------------------------------------
# ...

# %%
show_training_log('../LSTNet/save/full/electricity/electricity24_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: electricity24_history.csv
# Total Epochs: 100
# ...
#
# Epoch 1/100
# val_loss=0.081363, val_rse=0.6083977980841205, val_corr=nan, loss=0.135735, rse=0.881322, corr=0.297997
# ------------------------------------------------------------
# Epoch 2/100
# val_loss=0.065231, val_rse=0.5211899348411966, val_corr=nan, loss=0.072175, rse=0.514408, corr=0.763060
# ------------------------------------------------------------
# Epoch 3/100
# val_loss=0.060585, val_rse=0.4958997563453845, val_corr=nan, loss=0.062998, rse=0.467101, corr=0.812495
# ------------------------------------------------------------
# Epoch 4/100
# val_loss=0.058154, val_rse=0.48275563977920743, val_corr=nan, loss=0.059760, rse=0.450342, corr=0.827913
# ------------------------------------------------------------
# Epoch 5/100
# val_loss=0.056061, val_rse=0.4712689050792447, val_corr=nan, loss=0.057527, rse=0.438802, corr=0.837538
# ...

# %% [markdown]
# ## Training log của bộ dữ liệu exchange_rate.txt

# %%
show_training_log('../LSTNet/save/full/exchange/exchange3_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: exchange3_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.019949, val_rse=0.2792320170382109, val_corr=0.4574651773110994, loss=0.062868, rse=0.675509, corr=0.808294
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.016876, val_rse=0.24170334334822668, val_corr=0.4359428251213707, loss=0.014628, rse=0.175383, corr=0.966898
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.018273, val_rse=0.2523984343638062, val_corr=0.4418353744646306, loss=0.011545, rse=0.147830, corr=0.975299
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.017054, val_rse=0.24173475692002042, val_corr=0.4456070815464568, loss=0.011231, rse=0.145958, corr=0.975743
# ------------------------------------------------------------
# Epoch 5/25
# ...

# %%
show_training_log('../LSTNet/save/full/exchange/exchange6_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: exchange6_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.015569, val_rse=0.21166464904315857, val_corr=0.5862711006787769, loss=0.040299, rse=0.439349, corr=0.911477
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.014494, val_rse=0.19825217683403232, val_corr=0.5877322272663845, loss=0.009309, rse=0.119274, corr=0.983894
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.013174, val_rse=0.18675370172785205, val_corr=0.5895563473971622, loss=0.008911, rse=0.116667, corr=0.984657
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.012743, val_rse=0.18279457072652533, val_corr=0.5914244080092439, loss=0.008825, rse=0.115684, corr=0.984801
# ------------------------------------------------------------
# Epoch 5/25
# ...

# %%
show_training_log('../LSTNet/save/full/exchange/exchange12_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: exchange12_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.033737, val_rse=0.42130470735282294, val_corr=0.3748605969080969, loss=0.067814, rse=0.706829, corr=0.754660
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.021920, val_rse=0.29370152547818085, val_corr=0.3610044992645425, loss=0.017416, rse=0.205259, corr=0.950672
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.019261, val_rse=0.2692511952009754, val_corr=0.36779897643329285, loss=0.012641, rse=0.162296, corr=0.969984
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.019773, val_rse=0.2723554107550733, val_corr=0.36674106772866333, loss=0.012404, rse=0.161126, corr=0.970436
# ------------------------------------------------------------
# Epoch 5/25
# ...

# %%
show_training_log('../LSTNet/save/full/exchange/exchange24_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: exchange24_history.csv
# Total Epochs: 100
# ...
#
# Epoch 1/100
# val_loss=0.087822, val_rse=1.0531223696682293, val_corr=0.08296408520935396, loss=0.234539, rse=2.360647, corr=0.157385
# ------------------------------------------------------------
# Epoch 2/100
# val_loss=0.069962, val_rse=0.8590383964722021, val_corr=0.06946664522444936, loss=0.063693, rse=0.713034, corr=0.493248
# ------------------------------------------------------------
# Epoch 3/100
# val_loss=0.064539, val_rse=0.7669782438297046, val_corr=0.09426851101386531, loss=0.042321, rse=0.476284, corr=0.730742
# ------------------------------------------------------------
# Epoch 4/100
# val_loss=0.049244, val_rse=0.6266220800176125, val_corr=0.11708671172616981, loss=0.031440, rse=0.357585, corr=0.849837
# ------------------------------------------------------------
# Epoch 5/100
# ...

# %% [markdown]
# ## Training log của bộ dữ liệu solar.txt

# %%
show_training_log('../LSTNet/save/full/solar/solar3_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: solar3_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.057155, val_rse=inf, val_corr=nan, loss=0.086203, rse=0.550291, corr=0.847376
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.050480, val_rse=inf, val_corr=nan, loss=0.050691, rse=0.348586, corr=0.942248
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.043644, val_rse=inf, val_corr=nan, loss=0.045455, rse=0.317764, corr=0.951150
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.040063, val_rse=inf, val_corr=nan, loss=0.041929, rse=0.294909, corr=0.957699
# ------------------------------------------------------------
# Epoch 5/25
# val_loss=0.042432, val_rse=inf, val_corr=nan, loss=0.039426, rse=0.277783, corr=0.962477
# ------------------------------------------------------------
# Epoch 6/25
# ...

# %%
show_training_log('../LSTNet/save/full/solar/solar6_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: solar6_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.049401, val_rse=inf, val_corr=nan, loss=0.077205, rse=0.463224, corr=0.876044
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.046938, val_rse=inf, val_corr=nan, loss=0.049521, rse=0.325291, corr=nan
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.046293, val_rse=inf, val_corr=nan, loss=0.046211, rse=0.308916, corr=0.953641
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.048452, val_rse=inf, val_corr=nan, loss=0.044260, rse=0.298448, corr=0.956776
# ------------------------------------------------------------
# Epoch 5/25
# val_loss=0.042065, val_rse=inf, val_corr=nan, loss=0.042785, rse=inf, corr=nan
# ------------------------------------------------------------
# Epoch 6/25
# ...

# %%
show_training_log('../LSTNet/save/full/solar/solar12_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: solar12_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.081179, val_rse=inf, val_corr=nan, loss=0.119576, rse=0.657787, corr=0.814609
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.075872, val_rse=inf, val_corr=nan, loss=0.078408, rse=0.469333, corr=0.891802
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.065811, val_rse=inf, val_corr=nan, loss=0.069628, rse=0.434866, corr=0.907750
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.060844, val_rse=inf, val_corr=nan, loss=0.065163, rse=0.415262, corr=0.915839
# ------------------------------------------------------------
# Epoch 5/25
# val_loss=0.058457, val_rse=inf, val_corr=nan, loss=0.062348, rse=0.403571, corr=0.920402
# ------------------------------------------------------------
# Epoch 6/25
# ...

# %%
show_training_log('../LSTNet/save/full/solar/solar24_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: solar24_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.115499, val_rse=inf, val_corr=nan, loss=0.142170, rse=0.765636, corr=0.702901
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.081996, val_rse=inf, val_corr=nan, loss=0.102817, rse=0.581260, corr=0.824993
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.070601, val_rse=inf, val_corr=nan, loss=0.080164, rse=0.440942, corr=0.902374
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.066762, val_rse=inf, val_corr=nan, loss=0.069191, rse=0.402022, corr=0.920621
# ------------------------------------------------------------
# Epoch 5/25
# val_loss=0.062041, val_rse=inf, val_corr=nan, loss=0.064406, rse=0.387555, corr=0.926814
# ------------------------------------------------------------
# Epoch 6/25
# ...

# %% [markdown]
# ## Training log của bộ dữ liệu traffic.txt

# %%
show_training_log('../LSTNet/save/full/traffic/traffic3_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: traffic3_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.074491, val_rse=0.9338060817884292, val_corr=0.48016582441724037, loss=0.113786, rse=1.325979, corr=0.105557
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.057882, val_rse=0.7379042082241913, val_corr=0.6540916125364676, loss=0.062770, rse=0.817193, corr=0.567790
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.052747, val_rse=0.6835182063020373, val_corr=0.7039934048016685, loss=0.052926, rse=0.711161, corr=0.664095
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.046551, val_rse=0.6247872461719572, val_corr=0.7580012873762114, loss=0.046929, rse=0.645001, corr=0.721939
# ------------------------------------------------------------
# Epoch 5/25
# ...

# %%
show_training_log('../LSTNet/save/full/traffic/traffic6_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: traffic6_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.092997, val_rse=1.0962230923441476, val_corr=0.3634296987480708, loss=0.116764, rse=1.357721, corr=0.154382
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.077716, val_rse=0.9436421801677692, val_corr=0.5123242260588305, loss=0.083278, rse=1.036079, corr=0.440375
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.067097, val_rse=0.8364900178160549, val_corr=0.5818609572197508, loss=0.071216, rse=0.906156, corr=0.530095
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.058922, val_rse=0.7573340514440692, val_corr=0.6397862436085829, loss=0.062026, rse=0.811426, corr=0.593281
# ------------------------------------------------------------
# Epoch 5/25
# ...

# %%
show_training_log('../LSTNet/save/full/traffic/traffic12_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: traffic12_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.106222, val_rse=1.1751872645921944, val_corr=0.6399163148551967, loss=0.128922, rse=1.452063, corr=0.520730
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.067063, val_rse=0.8269476942202073, val_corr=0.6897065251530593, loss=0.068304, rse=0.857350, corr=0.596352
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.055466, val_rse=0.7141065670744786, val_corr=0.7283325811742412, loss=0.054716, rse=0.724915, corr=0.677714
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.050618, val_rse=0.6623066052577882, val_corr=0.7550045082833428, loss=0.048780, rse=0.664921, corr=0.716926
# ------------------------------------------------------------
# Epoch 5/25
# ...

# %%
show_training_log('../LSTNet/save/full/traffic/traffic24_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: traffic24_history.csv
# Total Epochs: 25
# ...
#
# Epoch 1/25
# val_loss=0.069495, val_rse=0.8494743809770675, val_corr=0.5964209794420637, loss=0.092066, rse=1.078515, corr=0.507610
# ------------------------------------------------------------
# Epoch 2/25
# val_loss=0.061828, val_rse=0.7783083524857535, val_corr=0.6402173904348011, loss=0.063975, rse=0.818102, corr=0.599649
# ------------------------------------------------------------
# Epoch 3/25
# val_loss=0.056073, val_rse=0.7243882135198, val_corr=0.6755385209638259, loss=0.057389, rse=0.754081, corr=0.640115
# ------------------------------------------------------------
# Epoch 4/25
# val_loss=0.051650, val_rse=0.684298749152124, val_corr=0.7038426506753728, loss=0.052375, rse=0.706859, corr=0.673892
# ------------------------------------------------------------
# Epoch 5/25
# ...
