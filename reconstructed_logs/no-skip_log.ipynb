# %%
import pandas as pd
import os
import sys
import numpy as np

# %%
import pandas as pd
import os
import sys
import numpy as np
import ast

def show_training_log(file_path, save_txt_path=None):
    """
    Hàm đọc file history (dạng dictionary chứa NaN và Infinity)
    """
    
    if not os.path.exists(file_path):
        print(f"❌ Lỗi: Không tìm thấy file tại '{file_path}'")
        return

    try:
        with open(file_path, 'r') as f:
            content = f.read().strip()
            
        try:
            context = {
                'NaN': np.nan, 
                'nan': np.nan,
                'Infinity': np.inf,
                'inf': np.inf,
                '-Infinity': -np.inf
            }
            
            data_dict = eval(content, {}, context)
            
            df = pd.DataFrame(data_dict)
            
        except Exception as e:
            print(f"⚠️ Lỗi parse Dictionary: {e}")
            print("👉 Đang thử đọc như CSV thông thường...")
            df = pd.read_csv(file_path)

        total_epochs = len(df)
        f_out = open(save_txt_path, 'w') if save_txt_path else None
        
        def log(text):
            print(text)
            if f_out: f_out.write(text + "\n")

        log("=" * 60)
        log(f"TRAINING LOG RECONSTRUCTION")
        log(f"Source: {os.path.basename(file_path)}")
        log(f"Total Epochs: {total_epochs}")
        log("=" * 60)
        log("") 

        if total_epochs == 0:
            print("❌ File rỗng.")
            return

        for i, row in df.iterrows():
            epoch = i + 1
            
            loss = row.get('loss', float('nan'))
            rse = row.get('rse', float('nan'))
            corr = row.get('corr', float('nan'))
            
            val_loss = row.get('val_loss', float('nan'))
            val_rse = row.get('val_rse', float('nan'))
            val_corr = row.get('val_corr', float('nan'))

            log(f"Epoch {epoch}/{total_epochs}")
            
            # Format chuỗi, xử lý in ra 'inf' nếu là vô cực
            log_line = (f"val_loss={val_loss:.6f}, val_rse={val_rse}, val_corr={val_corr}, "
                        f"loss={loss:.6f}, rse={rse:.6f}, corr={corr:.6f}")
            
            log(log_line)
            log("-" * 60) 

        if f_out:
            print(f"\n✅ Đã lưu log ra file: {save_txt_path}")
            f_out.close()
            
    except Exception as e:
        print(f"❌ Có lỗi xảy ra: {e}")

# %% [markdown]
# ## Training log của bộ dữ liệu electricity.txt

# %%
show_training_log('../LSTNet/save/no-skip/electricity3_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: electricity3_history.csv
# Total Epochs: 20
# ...
#
# Epoch 1/20
# val_loss=0.086031, val_rse=0.6373491140060882, val_corr=nan, loss=0.167128, rse=1.083988, corr=0.227371
# ------------------------------------------------------------
# Epoch 2/20
# val_loss=0.070572, val_rse=0.5286146069384192, val_corr=nan, loss=0.084117, rse=0.571488, corr=0.722042
# ------------------------------------------------------------
# Epoch 3/20
# val_loss=0.062702, val_rse=0.47416316992745744, val_corr=nan, loss=0.069886, rse=0.481356, corr=0.803578
# ------------------------------------------------------------
# Epoch 4/20
# val_loss=0.054896, val_rse=0.4215401014409757, val_corr=nan, loss=0.061385, rse=0.428025, corr=0.843667
# ------------------------------------------------------------
# Epoch 5/20
# val_loss=0.051750, val_rse=0.4016219778073149, val_corr=nan, loss=0.056001, rse=0.394445, corr=0.866598
# ------------------------------------------------------------
# ...

# %%
show_training_log('../LSTNet/save/no-skip/electricity6_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: electricity6_history.csv
# Total Epochs: 20
# ...
#
# Epoch 1/20
# val_loss=0.123495, val_rse=0.9215340043423951, val_corr=nan, loss=0.312861, rse=2.007967, corr=0.136237
# ------------------------------------------------------------
# Epoch 2/20
# val_loss=0
# ------------------------------------------------------------
# Epoch 4/20
# val_loss=0.100555, val_rse=inf, val_corr=nan, loss=0.102374, rse=0.663684, corr=0.783441
# ------------------------------------------------------------
# Epoch 5/20
# val_loss=0.072471, val_rse=inf, val_corr=nan, loss=0.098056, rse=0.612415, corr=0.812774
# ------------------------------------------------------------
# Epoch 6/20
# ...

# %% [markdown]
# ## Training log của bộ dữ liệu traffic.txt

# %%
show_training_log('../LSTNet/save/no-skip/traffic3_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: traffic3_history.csv
# Total Epochs: 20
# ...
#
# Epoch 1/20
# val_loss=0.105225, val_rse=1.199743802406809, val_corr=0.5802833542215006, loss=0.151357, rse=1.667438, corr=0.366790
# ------------------------------------------------------------
# Epoch 2/20
# val_loss=0.080891, val_rse=0.9635239389079288, val_corr=0.6325561761788134, loss=0.083258, rse=1.004864, corr=0.520245
# ------------------------------------------------------------
# Epoch 3/20
# val_loss=0.065129, val_rse=0.8025056320603806, val_corr=0.7012728125018318, loss=0.068876, rse=0.861830, corr=0.601043
# ------------------------------------------------------------
# Epoch 4/20
# val_loss=0.055809, val_rse=0.7034423590623676, val_corr=0.7501936823630747, loss=0.057668, rse=0.744654, corr=0.675114
# ------------------------------------------------------------
# Epoch 5/20
# ...

# %%
show_training_log('../LSTNet/save/no-skip/traffic6_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: traffic6_history.csv
# Total Epochs: 20
# ...
#
# Epoch 1/20
# val_loss=0.085229, val_rse=0.9921296236011573, val_corr=0.624023600975378, loss=0.132615, rse=1.489916, corr=0.208247
# ------------------------------------------------------------
# Epoch 2/20
# val_loss=0.061492, val_rse=0.7617869390725206, val_corr=0.7331192127215825, loss=0.066345, rse=0.802878, corr=0.604476
# ------------------------------------------------------------
# Epoch 3/20
# val_loss=0.052979, val_rse=0.676722934321482, val_corr=0.7709104693591612, loss=0.053495, rse=0.676993, corr=0.700444
# ------------------------------------------------------------
# Epoch 4/20
# val_loss=0.045900, val_rse=0.6034586710038434, val_corr=0.806830469377702, loss=0.045907, rse=0.604794, corr=0.757659
# ------------------------------------------------------------
# Epoch 5/20
# ...

# %%
show_training_log('../LSTNet/save/no-skip/traffic12_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: traffic12_history.csv
# Total Epochs: 20
# ...
#
# Epoch 1/20
# val_loss=0.068115, val_rse=0.8340914622947136, val_corr=0.6350871177608385, loss=0.083568, rse=1.001400, corr=0.552868
# ------------------------------------------------------------
# Epoch 2/20
# val_loss=0.055246, val_rse=0.7143904380935588, val_corr=0.6887496478980883, loss=0.060234, rse=0.780171, corr=0.643327
# ------------------------------------------------------------
# Epoch 3/20
# val_loss=0.049648, val_rse=0.6662332905633187, val_corr=0.7203965102651242, loss=0.051214, rse=0.696468, corr=0.686098
# ------------------------------------------------------------
# Epoch 4/20
# val_loss=0.046304, val_rse=0.639077793739908, val_corr=0.7394226178480167, loss=0.047032, rse=0.659688, corr=0.714025
# ------------------------------------------------------------
# Epoch 5/20
# ...

# %%
show_training_log('../LSTNet/save/no-skip/traffic24_history.csv')
# Out:
# ...
# TRAINING LOG RECONSTRUCTION
# Source: traffic24_history.csv
# Total Epochs: 20
# ...
#
# Epoch 1/20
# val_loss=0.088152, val_rse=1.0766431251867234, val_corr=0.3486711192705177, loss=0.139142, rse=1.627202, corr=-0.047695
# ------------------------------------------------------------
# Epoch 2/20
# val_loss=0.068631, val_rse=0.8538800574463296, val_corr=0.5972459312346832, loss=0.077654, rse=0.964814, corr=0.472260
# ------------------------------------------------------------
# Epoch 3/20
# val_loss=0.064607, val_rse=0.8352547026523058, val_corr=0.570105083513953, loss=0.065081, rse=0.830750, corr=0.585293
# ------------------------------------------------------------
# Epoch 4/20
# val_loss=0.054905, val_rse=0.7143889664924189, val_corr=0.696736059558463, loss=0.057197, rse=0.753015, corr=0.644533
# ------------------------------------------------------------
# Epoch 5/20
# ...
